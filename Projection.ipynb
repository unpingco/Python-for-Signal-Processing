# %% [markdown]
# Suppose we have a random variable, $X$, then what constant is closest to $X$ in the mean-squared-sense (MSE)? In other words, which $c$ minimizes the following:
#
# $$ J = \mathbb{E}( X - c )^2 $$
#
# we can work this out as
#
# $$ \mathbb{E}( X - c )^2 = \mathbb{E}(c^2 - 2 c X + X^2)  $$
#
# and then take the first derivative with respect to $c$ and solve:
#
# $$ c=\mathbb{E}(X) $$
#
# Remember that $X$ can take on all kinds of values, but this says that the closest number to $X$ in the MSE sense is $\mathbb{E}(X)$.

# %% [markdown]
# Let's continue our discussion of the conditional expectation operator by connecting it to the concept of projection.
#
# In the figure below, I want to find a point along the blue line that is closest to the red square. In other words, I want to inflate the pink circle until it just touches the blue line. Then, that point will be the closest point on the blue line to the red square.

# %%
from __future__ import division
from matplotlib import  patches

fig, ax = subplots()
x = arange(5)
y= matrix([[2],
           [3]])
ax.plot(x,x)
ax.plot(*y,marker='s',color='r')
ax.add_patch(patches.Circle(y,radius=.5,alpha=0.75,color='pink'))
ax.annotate('Find point along\n line closest\n to red square',
            fontsize=12,xy=(2.5,2.5),xytext=(3,1.5),arrowprops={'facecolor':'blue'})
ax.axis(xmax=5,ymax=4)
ax.set_aspect(1)
ax.grid()

# %% [markdown]
# It may be geometrically obvious, but the closest point on the line occurs where the line from the red square to the line is perpedicular to the line. At this point, the pink circle just touches the blue line.

# %%
fig, ax = subplots()
x = arange(5)
y= matrix([[2],
           [3]])
ax.plot(x,x)
ax.plot(*y,marker='o',color='r')
ax.add_patch(patches.Circle(y,radius=1/sqrt(2.),alpha=0.75,color='pink'))

v = matrix([[1],[1]]) 
Pv = v*v.T/ linalg.norm(v)**2 # projection operator
ax.plot(*(Pv*y),marker='s',color='g')
ax.add_line( Line2D( (y[0,0], 2.5), (y[1,0],2.5) ,color='g',linestyle='--'))
ax.add_line( Line2D( (y[0,0], 0), (y[1,0],0) ,color='r',linestyle='--'))
ax.annotate( 'Closest point is\nperpedicular\nto line',
              fontsize=12,xy=(2.6,2.5),xytext=(3,1.5),
              arrowprops={'facecolor':'blue'})

ax.text(.7,1.5,r'$\mathbf{y}$',fontsize=24,color='r')
ax.axis(xmax=5,ymax=4)
ax.set_aspect(1)
ax.grid()

# %% [markdown]
# Here is an arbitrary point along the blue line:
#
# $$ \mathbf{x} = \alpha \mathbf{v} $$
#
# where
#
# $$ \mathbf{v} = \left[ \begin{array}{c}
# 1 \\
# 1 \\
# \end{array} \right] $$
#
# so that $\alpha$ slides the point up and down the line. At the closest point, the vector between $\mathbf{y}$ and $\mathbf{x}$ (the dotted green line above) is perpedicular to the line. This means that
#
# $$ ( \mathbf{y}-\mathbf{x} )^T \mathbf{v} = 0$$
#
# and by substituting and working out the terms gives
#
# $$ \alpha = \frac{\mathbf{y}^T\mathbf{v}}{|\mathbf{v}|^2}  = \frac{1}{2} ( y_0 + y_1 )$$
#
# Using the Pythagorean theorem, we compute the squared length of the error as
#
# $$ \epsilon^2 = |( \mathbf{y}-\mathbf{x} )|^2 = |\mathbf{y}|^2 - \alpha^2 |\mathbf{v}|^2 = |\mathbf{y}|^2 - \frac{|\mathbf{y}^T\mathbf{v}|^2}{|\mathbf{v}|^2}  $$
#
# where $ |\mathbf{v}|^2 = \mathbf{v}^T \mathbf{v} $. Note that since $\epsilon^2 \ge 0 $, this also shows that
#
# $$ |\mathbf{y}^T\mathbf{v}| \le |\mathbf{y}|  |\mathbf{v}|   $$
#
# which is the famous Cauchy-Schwarz inequality. This inequality will soon be very important  for us.
#
# Finally, we can assemble all of this into the *projection* operator
#
# $$ \mathbf{P}_v = \frac{1}{|\mathbf{v}|^2 } \mathbf{v v}^T $$
#
# With this operator, we can take any given $\mathbf{y}$ and project it onto $\mathbf{v}$ by doing
#
# $$ \mathbf{P}_v \mathbf{y} $$
#
# It's called an operator because it takes a vector and produces another vector.

# %% [markdown]
# ### Weighted distances

# %%
theta = 45/180.*pi
v = matrix([[1],[1]])
#theta = 0
U = matrix([[ cos(theta), sin(theta)],
            [-sin(theta), cos(theta)]])

S = matrix([[10,0],
            [0,1]])

Q = U.T*S*U

Pv = (v)*v.T*(Q)/ (v.T*(Q)*v)
err = sqrt((y-Pv*y).T*Q*(y-Pv*y))
xhat = Pv*y
#Pvv = v*v.T*(S)/ (v.T*(S)*v)
#err = sqrt((y-Pvv*y).T*S*(y-Pvv*y))
#xi,yi = meshgrid( linspace(-3,3,30), linspace(-3,3,25) )
#quadform=(tensordot(dstack([xi,yi]),U.T*S,axes=1)*dstack([xi,yi])).sum(axis=2)

fig, ax = subplots()

#levels = linspace(quadform.min(), quadform.max(),5)
#levels = logspace(1,2,10).tolist()
#levels.append( .66 )
#ax.contour(xi+y[0,0],yi+y[1,0],quadform,cmap=cm.hot,levels=levels)
ax.plot(*y,marker='o',color='r')
ax.plot(x,x)
ax.plot(*(xhat),marker='s',color='r')
#ax.plot([2.33],[2.33],'g^')
ax.add_patch( patches.Ellipse(y,err*2/sqrt(S[0,0]),err*2/sqrt(S[1,1]),
                                angle=theta/pi*180,
                                alpha=0.5))
ax.add_line( Line2D( (y[0,0], 0), (y[1,0],0) ,color='r',linestyle='--'))
ax.add_line( Line2D( (y[0,0], xhat[0,0]), (y[1,0],xhat[1,0]) ,color='g',linestyle='--'))
#ax.add_patch( patches.Ellipse(y,err*2/sqrt(S[0,0]),err*2/sqrt(S[1,1]),alpha=0.5,color='g') )
ax.axis(xmax=5,ymax=4)
#ax.axis('equal')
ax.set_aspect(1)
ax.grid()

# %%
theta = 45/180.*pi
#theta = 0
U = matrix([[ cos(theta), sin(theta)],
            [-sin(theta), cos(theta)]])

S = matrix([[2,0],
            [0,1]])

vs = U*v
Pv = (vs)*vs.T*(S)/ (vs.T*(S)*vs)

fig, ax = subplots(1,2)

err = sqrt((U*y-Pv*U*y).T*S*(U*y-Pv*U*y))
ax[0].plot(*U*y,marker='o',color='r')
#ax.plot(x,x)
ax[0].plot(*(Pv*U*y),marker='s',color='g')
#ax.plot([2.33],[2.33],'g^')
#ax.add_patch( patches.Ellipse(y,err*2/sqrt(S[0,0]),err*2/sqrt(S[1,1]),angle=-theta/pi*180)) 
ax[0].add_patch( patches.Ellipse(U*y,err*2/sqrt(S[0,0]),err*2/sqrt(S[1,1]),alpha=0.5,color='g') )
ax[0].axis(xmin=0,xmax=5,ymax=4,ymin=-1)
ax[0].set_aspect(1)
ax[0].grid()

ax[1].plot(*y,marker='o',color='r')
ax[1].plot(x,x)
ax[1].plot(*(U.T*Pv*U*y),marker='s',color='g')
ax[1].add_patch( patches.Ellipse(y,err*2/sqrt(S[0,0]),err*2/sqrt(S[1,1]),alpha=0.5,color='g',angle=theta/pi*180. ))
ax[1].axis(xmin=0,xmax=5,ymax=4,ymin=-1)
ax[1].set_aspect(1)
ax[1].grid()
