# %%
# %matplotlib inline

# %% [markdown]
# ## Revisiting Linear Regression

# %% [markdown]
# In our previous discussion  on linear regression, we saw that regularization  can help trade bias against  variance

# %%
a = 6;b=1
n=100

x = linspace(0,1,n)
y  = a*x + b +randn(n)
a_,b_ = polyfit(x,y,1)

# %%
fig,axs=subplots(1,2)
fig.set_size_inches((10,3))

ax=axs[0]
ax.plot(x,y,'o',alpha=.3)
ax.plot(x,polyval([a_,b_],x))

ax = axs[1]
ax.hist(polyval([a_,b_],x)-y)
# Out:
# (array([  2.,   9.,   5.,  15.,  24.,  17.,  18.,   6.,   2.,   2.]),
#  array([-2.26251989, -1.78473832, -1.30695675, -0.82917518, -0.35139361,
#          0.12638796,  0.60416953,  1.0819511 ,  1.55973267,  2.03751424,
#          2.51529581]),
#  <a list of 10 Patch objects>)
