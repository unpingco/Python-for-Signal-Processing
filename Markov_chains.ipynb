# %% [markdown]
# # Basic Definitions

# %% [markdown]
# # Multistep Transitions

# %% [markdown]
# # Classification of States

# %% [markdown]
# # Steady-State Behavior

# %% [markdown]
# # Examples
